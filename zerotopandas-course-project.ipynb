# %% [markdown]
# ## Data Analysis with Python: Zero to Pandas - Course Project
#
# # Covid-19 Analysis
# COVID-2019 has been recognized as a global threat, and several studies are being conducted in order to contribute to the fight and prevention of this pandemic. We have tried to represent the basic trends in the cases or casualities using the graphical representation by exploring desired dataset.I highly recommend the course [Data Analysis with Python: Zero to Pandas](zerotopandas.com) to all my mates who are intresting  in the field of *DATA ANALYTICS and DATA SCIENCE*, and this course gives me the best exposure and hands on learning on the skills that are required in data analytics.

# %% [markdown]
# ## Downloading the Dataset
# We have downloaded the covid-19 dataset from the kaggle website.
#            Link :- https://www.kaggle.com/datasets/jillanisofttech/covid-19-dataset

# %%
# importing the required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# The dataset has been downloaded and extracted.
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "course-project-EDA-on-covid"

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# *We have readed the data with the help of read_csv function and stored it into a new dataframe named covid_df so that it can be further processed and accessed. Then we have checked for missing value and incorrect value by using the .isna, min(), max() methods.*
#
# *Atlast we have added some of the required columns in the dataframe by performing some of the mathematical calculations.*

# %%
# Loading the dataset into a data frame using Pandas
covid_df = pd.read_csv('country_wise_latest.csv')
covid_df
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered
# 0            10             18
# ...

# %%
# Exploring the number of rows & columns
covid_df.shape
# Out:
# (187, 8)

# %%
covid_df.sample(10)
# Out:
#          Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 107         Mali       2513     124       1913     476          3           1
# 1        Albania       4880     144       2745    1991        117           6
# 172       Turkey     227019    5630     210469   10920        919          17
# 45        Cyprus       1060      19        852     189          3           0
# 141  Saint Lucia         24       0         22       2          0           0
# 136        Qatar     109597     165     106328    3104        292           0
# 171      Tunisia       1455      50       1157     248          3           0
# 158    Sri Lanka       2805      11       2121     673         23           0
# 68     Greenland         14       0         13       1          1           0
# 7        Armenia      37390     711      26665   10014         73           6
#
#      New recovered
# 107              2
# 1               63
# 172            982
# 45               0
# ...

# %%
# Handle missing, incorrect and invalid data
covid_df[['Confirmed','Deaths','Recovered','Active','New cases','New deaths','New recovered']].min()
# Out:
# Confirmed        10
# Deaths            0
# Recovered         0
# Active            0
# New cases         0
# New deaths        0
# New recovered     0
# dtype: int64

# %%
covid_df[['Confirmed','Deaths','Recovered','Active','New cases','New deaths','New recovered']].max()
# Out:
# Confirmed        4290259
# Deaths            148011
# Recovered        1846641
# Active           2816444
# New cases          56336
# New deaths          1076
# New recovered      33728
# dtype: int64

# %%
# All the values are present in the required columns
from IPython.display import display
with pd.option_context('display.max_rows', 200):
    display(covid_df.isna())
# Out:
#      Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0      False      False   False      False   False      False       False
# 1      False      False   False      False   False      False       False
# 2      False      False   False      False   False      False       False
# 3      False      False   False      False   False      False       False
# 4      False      False   False      False   False      False       False
# 5      False      False   False      False   False      False       False
# 6      False      False   False      False   False      False       False
# 7      False      False   False      False   False      False       False
# 8      False      False   False      False   False      False       False
# 9      False      False   False      False   False      False       False
# 10     False      False   False      False   False      False       False
# 11     False      False   False      False   False      False       False
# ...

# %%
# Performing any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)
covid_df['Recovery_rate'] = (covid_df.Recovered / covid_df.Confirmed)*100
covid_df['Death_rate'] = (covid_df.Deaths / covid_df.Confirmed)*100
covid_df
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Recovery_rate  Death_rate
# ...

# %%
world_df = pd.read_csv('worldometer_data.csv')
world_df.drop(columns=['TotalCases','NewCases','TotalDeaths','NewDeaths','TotalRecovered','NewRecovered','ActiveCases','Serious,Critical','Tot Cases/1M pop','Deaths/1M pop','TotalTests','Tests/1M pop','WHO Region'],inplace = True)
world_df
# Out:
#                    Country      Continent    Population
# 0                      USA  North America  3.311981e+08
# 1                   Brazil  South America  2.127107e+08
# 2                    India           Asia  1.381345e+09
# 3                   Russia         Europe  1.459409e+08
# 4             South Africa         Africa  5.938157e+07
# ..                     ...            ...           ...
# 204             Montserrat  North America  4.992000e+03
# 205  Caribbean Netherlands  North America  2.624700e+04
# 206       Falkland Islands  South America  3.489000e+03
# 207           Vatican City         Europe  8.010000e+02
# 208         Western Sahara         Africa  5.986820e+05
#
# [209 rows x 3 columns]

# %%
merged_df = covid_df.merge(world_df,on='Country')

# %%
merged_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0       Afghanistan      36263    1269      25198    9796        106
# 1           Albania       4880     144       2745    1991        117
# 2           Algeria      27973    1163      18837    7973        616
# 3           Andorra        907      52        803      52         10
# 4            Angola        950      41        242     667         18
# ..              ...        ...     ...        ...     ...        ...
# 166         Vietnam        431       0        365      66         11
# 167  Western Sahara         10       1          8       1          0
# 168           Yemen       1691     483        833     375         10
# 169          Zambia       4552     140       2815    1597         71
# 170        Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Recovery_rate  Death_rate Continent  \
# 0            10             18      69.486805    3.499435      Asia
# ...

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# Here in this block of the Notebook we have performed the *Data manipulation* by applying some of the mathematical operations on the column and visualizes it into the required *Graph or plot* that it can shows us the insights of the data and about it's trends.
#
# Tasks Perofrmed :-
# > - Computing the mean, sum and other interesting statistics for numeric columns
# > - Exploring distributions of numeric columns using histograms etc.
# > - Exploring relationship between columns using scatter plots, bar charts etc.
# > - Making a note of interesting insights from the exploratory analysis

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (12, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **Computing the mean, sum, range and other interesting statistics for Dataset columns**

# %%
# Computing the mean, sum, range and other interesting statistics for numeric columns
merged_df.describe()
# Out:
#           Confirmed        Deaths     Recovered         Active     New cases  \
# count  1.710000e+02    171.000000  1.710000e+02     171.000000    171.000000
# mean   6.828658e+04   2656.046784  4.660423e+04   19026.304094    995.777778
# std    2.360898e+05   9084.222625  1.726746e+05   60466.101756   4201.294138
# min    1.000000e+01      0.000000  0.000000e+00       0.000000      0.000000
# 25%    1.130000e+03     19.500000  6.515000e+02     146.000000      5.000000
# 50%    4.881000e+03    112.000000  2.815000e+03    1599.000000     49.000000
# 75%    4.046050e+04    804.000000  2.330300e+04    9826.500000    432.500000
# max    2.442375e+06  87618.000000  1.846641e+06  508116.000000  44457.000000
#
#        New deaths  New recovered  Recovery_rate  Death_rate    Population
# count  171.000000     171.000000     171.000000  171.000000  1.710000e+02
# mean    25.152047     850.994152      64.839096    3.060729  3.300425e+07
# ...

# %%
merged_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0       Afghanistan      36263    1269      25198    9796        106
# 1           Albania       4880     144       2745    1991        117
# 2           Algeria      27973    1163      18837    7973        616
# 3           Andorra        907      52        803      52         10
# 4            Angola        950      41        242     667         18
# ..              ...        ...     ...        ...     ...        ...
# 166         Vietnam        431       0        365      66         11
# 167  Western Sahara         10       1          8       1          0
# 168           Yemen       1691     483        833     375         10
# 169          Zambia       4552     140       2815    1597         71
# 170        Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Recovery_rate  Death_rate Continent  \
# 0            10             18      69.486805    3.499435      Asia
# ...

# %% [markdown]
# **Here we found the total population of each continent by using the groupby() function of pandas library and then we have plotted the line chart that represents us that which continent has the highest population.**

# %%
population_df = merged_df.groupby('Continent')['Population'].sum()
population_df
# Out:
# Continent
# Africa               1.215738e+09
# Asia                 3.020510e+09
# Australia/Oceania    4.039107e+07
# Europe               6.794130e+08
# North America        2.568683e+08
# South America        4.308076e+08
# Name: Population, dtype: float64

# %%
plt.plot(population_df,'o-b')
plt.xlabel('Continents')
plt.ylabel('Population in Billions')
plt.title("Continents-Population");

# %% [markdown]
# **Here we have drawn a scatter plot chart which tells us the insights of *Death Rate* v/s the *Recovery Rate* of the patients who suffred from the Covid Pandemic.**
# **According to the trend that we have seen in this graph *we can conclude that among all the continents Asia* is the richest country in terms of population.**

# %%
rate_df = merged_df.groupby('Continent')[['Recovery_rate','Death_rate']].mean()
rate_df
# Out:
#                    Recovery_rate  Death_rate
# Continent
# Africa                 58.079084    2.496852
# Asia                   70.761348    2.211356
# Australia/Oceania      60.622790    0.626066
# Europe                 68.698557    4.802634
# North America          65.815564    2.959821
# South America          59.935449    3.188326

# %%
plt.title('Death V/S Recovery chart')
sns.scatterplot(x='Recovery_rate', 
                y='Death_rate', 
                hue='Continent',
                s=100,
                data=rate_df);
plt.legend(loc = 'upper left',fontsize=12);

# %%
# Top 10 countries with highest active cases
active_df = merged_df.sort_values('Active', ascending=False).head(10)
active_df
# Out:
#           Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 23         Brazil    2442375   87618    1846641  508116      23284
# 71          India    1480073   33408     951166  495499      44457
# 129        Russia     816680   13334     602249  201097       5607
# 144  South Africa     452529    7067     274925  170537       7096
# 33       Colombia     257101    8777     131161  117163      16306
# 54         France     220352   30212      81212  108928       2551
# 30         Canada     116458    8944          0  107514        682
# 123          Peru     389717   18418     272547   98752      13756
# 13     Bangladesh     226225    2965     125683   97577       2772
# 146         Spain     272421   28432     150376   93613          0
#
#      New deaths  New recovered  Recovery_rate  Death_rate      Continent  \
# 23          614          33728      75.608414    3.587410  South America
# 71          637          33598      64.264803    2.257186           Asia
# ...

# %%
sns.barplot(y='Country',x='Active',data = active_df);

# %% [markdown]
# **Here we have plotted the horizontal bar chart or we can say a bar plot which describes us the top 10 countries with highest number of active cases.**

# %%
population_df = merged_df.groupby('Continent')['Deaths'].sum()
population_df
# Out:
# Continent
# Africa                17759
# Asia                  85740
# Australia/Oceania       189
# Europe               155775
# North America         59215
# South America        135506
# Name: Deaths, dtype: int64

# %%
# Pie chart
labels = ['Africa','Asia','Australia','Europe','North America','South America']
sizes = population_df
explode = (0, 0, 0, 0.1,0,0)
plt.pie(sizes,labels=labels,explode=explode);

# %% [markdown]
# **Here we have plotted the the pie chart by finding the continent which has the hghest death count across all other continents.**

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %% [markdown]
# ## Asking and Answering Questions
#
# In this secion of the Notebook we have performed multple mathematical operations and functions on the columns of table with the help of *Pandas* library and each functions that we have used in this section are explained above the function used.

# %% [markdown]
# ### Q1: In the continent region there are plenty of Countries. Find the country of the *Asia continent* which has highest number of active cases.

# %% [markdown]
# ### Merged_df function
# #### *merged_df()* is used to merged two dataframes where one columnand their entries must be common in both.

# %%
high_active_df = merged_df[merged_df.Continent=="Asia"]
high_active_df
# Out:
#           Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0     Afghanistan      36263    1269      25198    9796        106
# 7         Armenia      37390     711      26665   10014         73
# 10     Azerbaijan      30446     423      23242    6781        396
# 12        Bahrain      39482     141      36110    3231        351
# 13     Bangladesh     226225    2965     125683   97577       2772
# 19         Bhutan         99       0         86      13          4
# 28       Cambodia        226       0        147      79          1
# 38         Cyprus       1060      19        852     189          3
# 57        Georgia       1137      16        922     199          6
# 71          India    1480073   33408     951166  495499      44457
# 72      Indonesia     100303    4838      58173   37292       1525
# 73           Iran     293606   15912     255144   22550       2434
# 74           Iraq     112585    4458      77144   30983       2553
# ...

# %% [markdown]
# ### sort_values and head function
# #### *sort_values()* is used to sort the values either in the ascending or in the descending order. *head()* is used to get the number of rows from the top of the dataset or dataframe. By default it returns the top 5 rows.

# %%
high = high_active_df.sort_values('Active',ascending=False).head(1)

# %%
high[['Continent','Country','Active']]
# Out:
#    Continent Country  Active
# 71      Asia   India  495499

# %% [markdown]
# ### Q2: Find out the top 10 countries which has the Best Recovery Rate all over the world and print the countries and Recovery rate.

# %%
top_10_df = merged_df.sort_values('Recovery_rate',ascending=False).head(10)

# %%
top_10_df
# Out:
#          Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 42      Dominica         18       0         18       0          0           0
# 62       Grenada         23       0         23       0          0           0
# 41      Djibouti       5059      58       4977      24          9           0
# 70       Iceland       1854      10       1823      21          7           0
# 112  New Zealand       1557      22       1514      21          1           0
# 127        Qatar     109597     165     106328    3104        292           0
# 96      Malaysia       8904     124       8601     179          7           0
# 101    Mauritius        344      10        332       2          0           0
# 117       Norway       9132     255       8752     125         15           0
# 85          Laos         20       0         19       1          0           0
#
#      New recovered  Recovery_rate  Death_rate          Continent  Population
# ...

# %%
top_10_df[['Country','Recovery_rate']]
# Out:
#          Country  Recovery_rate
# 42      Dominica     100.000000
# 62       Grenada     100.000000
# 41      Djibouti      98.379126
# 70       Iceland      98.327940
# 112  New Zealand      97.238279
# 127        Qatar      97.017254
# 96      Malaysia      96.597035
# 101    Mauritius      96.511628
# 117       Norway      95.838809
# 85          Laos      95.000000

# %% [markdown]
# ### Q3: Add all the data of new columns like (*New cases,New deaths,New recovered*) in the original data columns (*Confirmed,Deaths,Recovered*) After performing all these operations drop the old columns.

# %%
merged_df['Confirmed'] = merged_df['Confirmed'] + merged_df['New cases']
merged_df['Deaths'] = merged_df['Deaths'] + merged_df['New deaths']
merged_df['Recovered'] = merged_df['Recovered'] + merged_df['New recovered']
merged_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  New cases  \
# 0       Afghanistan      36369    1279      25216    9796        106
# 1           Albania       4997     150       2808    1991        117
# 2           Algeria      28589    1171      19586    7973        616
# 3           Andorra        917      52        803      52         10
# 4            Angola        968      42        242     667         18
# ..              ...        ...     ...        ...     ...        ...
# 166         Vietnam        442       0        365      66         11
# 167  Western Sahara         10       1          8       1          0
# 168           Yemen       1701     487        869     375         10
# 169          Zambia       4623     141       3280    1597         71
# 170        Zimbabwe       2896      38        566    2126        192
#
#      New deaths  New recovered  Recovery_rate  Death_rate Continent  \
# 0            10             18      69.486805    3.499435      Asia
# ...

# %% [markdown]
# ### drop function
# #### *drop()* function deletes or removes the columns on the given dataset.

# %%
merged_df.drop(columns=['New cases','New deaths','New recovered'],inplace=True)
merged_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  Recovery_rate  \
# 0       Afghanistan      36369    1279      25216    9796      69.486805
# 1           Albania       4997     150       2808    1991      56.250000
# 2           Algeria      28589    1171      19586    7973      67.339935
# 3           Andorra        917      52        803      52      88.533627
# 4            Angola        968      42        242     667      25.473684
# ..              ...        ...     ...        ...     ...            ...
# 166         Vietnam        442       0        365      66      84.686775
# 167  Western Sahara         10       1          8       1      80.000000
# 168           Yemen       1701     487        869     375      49.260792
# 169          Zambia       4623     141       3280    1597      61.840949
# 170        Zimbabwe       2896      38        566    2126      20.044379
#
#      Death_rate Continent  Population
# 0      3.499435      Asia  39009447.0
# ...

# %% [markdown]
# ### Q4: Perform the aggregate operations on the columns that are amicable and performable for same of Dataset table.

# %%
merged_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  Recovery_rate  \
# 0       Afghanistan      36369    1279      25216    9796      69.486805
# 1           Albania       4997     150       2808    1991      56.250000
# 2           Algeria      28589    1171      19586    7973      67.339935
# 3           Andorra        917      52        803      52      88.533627
# 4            Angola        968      42        242     667      25.473684
# ..              ...        ...     ...        ...     ...            ...
# 166         Vietnam        442       0        365      66      84.686775
# 167  Western Sahara         10       1          8       1      80.000000
# 168           Yemen       1701     487        869     375      49.260792
# 169          Zambia       4623     141       3280    1597      61.840949
# 170        Zimbabwe       2896      38        566    2126      20.044379
#
#      Death_rate Continent  Population
# 0      3.499435      Asia  39009447.0
# ...

# %%
print("The sum of the columns as per values are :- ")
merged_df[['Confirmed','Deaths','Recovered','Active','Population']].sum()
# Out:
# The sum of the columns as per values are :-
# Confirmed     1.184728e+07
# Deaths        4.584850e+05
# Recovered     8.114844e+06
# Active        3.253498e+06
# Population    5.643727e+09
# dtype: float64

# %%
print("The mean of the columns as per values are :- ")
merged_df[['Confirmed','Deaths','Recovered','Active','Recovery_rate','Death_rate','Population']].mean()
# Out:
# The mean of the columns as per values are :-
# Confirmed        6.928236e+04
# Deaths           2.681199e+03
# Recovered        4.745523e+04
# Active           1.902630e+04
# Recovery_rate    6.483910e+01
# Death_rate       3.060729e+00
# Population       3.300425e+07
# dtype: float64

# %% [markdown]
# ### Q5: After performing all the operations write back the data to file (like *added columns, manipulated or updtaed data*) in the form of dataset in the new file of extension *csv* .

# %%
Final_df = merged_df[['Country','Confirmed','Deaths','Recovered','Active','Recovery_rate','Death_rate','Continent','Population']]

# %%
Final_df
# Out:
#             Country  Confirmed  Deaths  Recovered  Active  Recovery_rate  \
# 0       Afghanistan      36369    1279      25216    9796      69.486805
# 1           Albania       4997     150       2808    1991      56.250000
# 2           Algeria      28589    1171      19586    7973      67.339935
# 3           Andorra        917      52        803      52      88.533627
# 4            Angola        968      42        242     667      25.473684
# ..              ...        ...     ...        ...     ...            ...
# 166         Vietnam        442       0        365      66      84.686775
# 167  Western Sahara         10       1          8       1      80.000000
# 168           Yemen       1701     487        869     375      49.260792
# 169          Zambia       4623     141       3280    1597      61.840949
# 170        Zimbabwe       2896      38        566    2126      20.044379
#
#      Death_rate Continent  Population
# 0      3.499435      Asia  39009447.0
# ...

# %% [markdown]
# ### to_csv Function
# #### to_csv() is used to create a new csv file by passing the dataset in a particular dataframe as per the required syntax.

# %%
Final_df.to_csv('Final_dataset.csv',index = None)

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %% [markdown]
# ## Inferences and Conclusion
#
# **According to all the results that we find in this notebook after performing all the calculations, manipulations and operaions on the kaggle covid dataset. we have concluded some of the points and aspects which can be shown as the results and insights of this notebook and the Dataset.**
#
# Some of the following are :-
#
# >-Handled missing, incorrect and invalid data,calculated Recovery_rate,Death_rate, Highest active cases, deaths among the countries and the continent.
#
# >Visualizes the following chart :-
#         >- Continents-population
#         >- Death v/s Recovery
#         >- top 10 countries with highest number of active cases
#         >- highest death among all the continents

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %% [markdown]
# ## References and Future Work
#
# This dataset that contains only the overall information of the covid-19 confimed cases, deaths, Recovered,etc. but if dataset should enhanced in future and it should as we are still living in the Covid surrounded environment. So further this project can be updated according to the requirements and harmony.
#
# The dataset is colleceted from the well known dataset site known as *Kaggle*. Here is the link of the dataset that we have collected.
#
# Link :- https://www.kaggle.com/datasets/jillanisofttech/covid-19-dataset
#
# Atlast I am thankful for the Hands-on learning exposure of Data Analysis with Python: Zero to Pandas  Course offered by https://jovian.ai

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "tkdaniruddha/course-project-eda-on-covid" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/tkdaniruddha/course-project-eda-on-covid
# 'https://jovian.ai/tkdaniruddha/course-project-eda-on-covid'

# %%
(13 * 5 + 65) / 10
# Out:
# 13.0

# %%
print("{:.2f}".format(a))
# Out:
# 3.33
